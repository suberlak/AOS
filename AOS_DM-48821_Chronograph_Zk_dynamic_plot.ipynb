# %% [markdown]
# # DM-48821  Chronograph: Add AOS plot dynamically plotting Zk results

# %%
N = 4
def get_chronograph_query(N):
    a = '''
import "experimental"

from(bucket: "efd/autogen")
  |> range(start: v.timeRangeStart, stop: v.timeRangeStop)
  |> filter(fn: (r) => r["_measurement"] == "lsst.sal.MTAOS.logevent_wavefrontError")
  |> pivot(rowKey: ["_time"], columnKey: ["_field"], valueColumn: "_value")
  |> map(fn: (r) => {
      // Check all possible index values manually
    '''
    b = f'''    zk_value = if exists r.nollZernikeIndices0 and r.nollZernikeIndices0 == {N} then r.nollZernikeValues0
      else if exists r.nollZernikeIndices1 and r.nollZernikeIndices1 == {N} then r.nollZernikeValues1
      else if exists r.nollZernikeIndices2 and r.nollZernikeIndices2 == {N} then r.nollZernikeValues2
      else if exists r.nollZernikeIndices3 and r.nollZernikeIndices3 == {N} then r.nollZernikeValues3
      else if exists r.nollZernikeIndices4 and r.nollZernikeIndices4 == {N} then r.nollZernikeValues4
      else if exists r.nollZernikeIndices5 and r.nollZernikeIndices5 == {N} then r.nollZernikeValues5
      else if exists r.nollZernikeIndices6 and r.nollZernikeIndices6 == {N} then r.nollZernikeValues6
      else if exists r.nollZernikeIndices7 and r.nollZernikeIndices7 == {N} then r.nollZernikeValues7
      else if exists r.nollZernikeIndices8 and r.nollZernikeIndices8 == {N} then r.nollZernikeValues8
      else if exists r.nollZernikeIndices9 and r.nollZernikeIndices9 == {N} then r.nollZernikeValues9
      else if exists r.nollZernikeIndices10 and r.nollZernikeIndices10 == {N} then r.nollZernikeValues10
      else if exists r.nollZernikeIndices11 and r.nollZernikeIndices11 == {N} then r.nollZernikeValues11
      else if exists r.nollZernikeIndices12 and r.nollZernikeIndices12 == {N} then r.nollZernikeValues12
      else if exists r.nollZernikeIndices13 and r.nollZernikeIndices13 == {N} then r.nollZernikeValues13
      else if exists r.nollZernikeIndices14 and r.nollZernikeIndices14 == {N} then r.nollZernikeValues14
      else if exists r.nollZernikeIndices15 and r.nollZernikeIndices15 == {N} then r.nollZernikeValues15
      else if exists r.nollZernikeIndices16 and r.nollZernikeIndices16 == {N} then r.nollZernikeValues16
      else if exists r.nollZernikeIndices17 and r.nollZernikeIndices17 == {N} then r.nollZernikeValues17
      else if exists r.nollZernikeIndices18 and r.nollZernikeIndices18 == {N} then r.nollZernikeValues18
      else if exists r.nollZernikeIndices19 and r.nollZernikeIndices19 == {N} then r.nollZernikeValues19
      else if exists r.nollZernikeIndices20 and r.nollZernikeIndices20 == {N} then r.nollZernikeValues20
      else if exists r.nollZernikeIndices21 and r.nollZernikeIndices21 == {N} then r.nollZernikeValues21
      else if exists r.nollZernikeIndices22 and r.nollZernikeIndices22 == {N} then r.nollZernikeValues22
      else if exists r.nollZernikeIndices23 and r.nollZernikeIndices23 == {N} then r.nollZernikeValues23
      else if exists r.nollZernikeIndices24 and r.nollZernikeIndices24 == {N} then r.nollZernikeValues24
      else if exists r.nollZernikeIndices25 and r.nollZernikeIndices25 == {N} then r.nollZernikeValues25
      else if exists r.nollZernikeIndices26 and r.nollZernikeIndices26 == {N} then r.nollZernikeValues26
      else if exists r.nollZernikeIndices27 and r.nollZernikeIndices27 == {N} then r.nollZernikeValues27
      else 0.0
              '''
    c = '''         
  return { _time: r._time, _value: zk_value }
})
|> aggregateWindow(every: v.windowPeriod, fn: mean, createEmpty: false)
|> rename(columns: {_value: ''' + f'"Zk{N}"'+'''})  // <-- Final rename for plotting
|> yield(name: "mean")'''
    
    print(a+b+c)
    return

# %%
for N in range(4,29):
    get_chronograph_query(N)
# Out:
# import "experimental"
#
# from(bucket: "efd/autogen")
#   |> range(start: v.timeRangeStart, stop: v.timeRangeStop)
#   |> filter(fn: (r) => r["_measurement"] == "lsst.sal.MTAOS.logevent_wavefrontError")
#   |> pivot(rowKey: ["_time"], columnKey: ["_field"], valueColumn: "_value")
#   |> map(fn: (r) => {
#       // Check all possible index values manually
#         zk_value = if exists r.nollZernikeIndices0 and r.nollZernikeIndices0 == 4 then r.nollZernikeValues0
#       else if exists r.nollZernikeIndices1 and r.nollZernikeIndices1 == 4 then r.nollZernikeValues1
#       else if exists r.nollZernikeIndices2 and r.nollZernikeIndices2 == 4 then r.nollZernikeValues2
#       else if exists r.nollZernikeIndices3 and r.nollZernikeIndices3 == 4 then r.nollZernikeValues3
#       else if exists r.nollZernikeIndices4 and r.nollZernikeIndices4 == 4 then r.nollZernikeValues4
#       else if exists r.nollZernikeIndices5 and r.nollZernikeIndices5 == 4 then r.nollZernikeValues5
# ...
