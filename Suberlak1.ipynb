# %%
import os

import lsst.daf.butler as dafButler
import lsst.afw.display as afwDisplay

# %matplotlib ipympl
#%matplotlib inline
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (12, 10)

# %%
afwDisplay.setDefaultBackend("matplotlib")

# need to specify the calib collections to be able to access the camera 
repo_name = 'DATA'
repo_dir = os.path.join('/project/scichris/aos/ps1_phosim/testBkgnd/arrowsComCam_fixGain',repo_name)

butler = dafButler.Butler(repo_dir)
exp = butler.get('postISRCCD', detector='R22_S00', instrument="LSSTComCam",
          exposure=4000021706001,collections=['run1'])

# %%
from astropy.io import fits
hdul  = fits.open('/project/scichris/aos/ps1_phosim/testBkgnd/\
arrowsComCam_fixGain/repackaged/CC_H_20000217_006001_R22_S00.fits')
hdul[1].header
# Out:
# XTENSION= 'IMAGE   '           / Image extension
# BITPIX  =                   32 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                  544
# NAXIS2  =                 2048
# PCOUNT  =                    0 / number of parameters
# GCOUNT  =                    1 / number of groups
# BSCALE  =                    1
# BZERO   =           2147483648
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# CTYPE1  = 'RA---TAN'
# CRPIX1  =               -5719.
# CRVAL1  =                   0.
# CTYPE2  = 'DEC--TAN'
# CRPIX2  =               -2179.
# CRVAL2  =                   0.
# CD1_1   =                   0.
# CD1_2   = -5.55555555555556E-05
# CD2_1   = -5.55555555555556E-05
# CD2_2   =                  -0.
# RADESYS = 'ICRS    '
# EQUINOX =                2000.
# PHOV0   = 'nframes 1'          / Physics Override Command 0
# ...

# %%
# dataId = dict(detector='R22_S00', exposure=4016091606002)
# exp = butler.get('postISRCCD', dataId)

# %%
fig = 1
if True:
    plt.close(fig); fig = plt.figure(fig)
    disp = afwDisplay.Display(fig)
    plt.sca(fig.gca())

else:
    disp = afwDisplay.Display(fig, reopenPlot=True)
    plt.sca(fig)

disp.setImageColormap('gray' if True else 'viridis')
disp.scale('linear', 'zscale' )

det = exp.getDetector()
disp.mtv(exp, title=f'LsstComCam, {det.getName()} ({det.getPhysicalType()})')

plt.xlabel('x [px]')
plt.ylabel('y [px]');
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
