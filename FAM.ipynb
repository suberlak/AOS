# %%
from lsst.ts.wep.SourceProcessor import SourceProcessor
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-b82dcb5896da> in <module>
# ----> 1 from lsst.ts.wep.SourceProcessor import SourceProcessor
#
# ModuleNotFoundError: No module named 'lsst.ts'

# %% [markdown]
# Just one amplifier shows that the extra-focal images for the Full-Array Mode camera were completed on lsst-devl01.  The intra-focal didn't manage to get finished before the system maintenance shutdown.

# %%
import astropy.io.fits as fits
import os 
import matplotlib.pyplot as plt 
workDir = '/project/scichris/aos/results_gaia/dr2_med_full_2020_24_wide_lsstfamcam_NCSA/iter0/img/extra/'
fits_path = os.path.join(workDir,'lsst_a_9006001_f1_R31_S02_C01_E000.fits.gz')
hdul = fits.open(fits_path)
img0 = hdul[0].data
fig,ax = plt.subplots(1,1,figsize=(5,10))
ax.imshow(img0)
